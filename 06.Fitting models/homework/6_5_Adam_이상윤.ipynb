# %%
# import libraries
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# %%
# Define function that we wish to find the minimum of (normally would be defined implicitly by data and loss)
"""Nonconvex Function"""
def loss(phi0, phi1):
    height = np.exp(-0.5 * (phi1 * phi1)*4.0)
    height = height * np. exp(-0.5* (phi0-0.7) *(phi0-0.7)/4.0)
    return 1.0-height

# %%
# Compute the gradients of this function (for simplicity, I just used finite differences)
def get_loss_gradient(phi0, phi1):
    delta_phi = 0.00001;
    gradient = np.zeros((2,1));
    gradient[0] = (loss(phi0+delta_phi/2.0, phi1) - loss(phi0-delta_phi/2.0, phi1))/delta_phi
    gradient[1] = (loss(phi0, phi1+delta_phi/2.0) - loss(phi0, phi1-delta_phi/2.0))/delta_phi
    return gradient[:,0];

# %%
# Compute the loss function at a range of values of phi0 and phi1 for plotting
def get_loss_function_for_plot():
  grid_values = np.arange(-1.0,1.0,0.01);
  phi0mesh, phi1mesh = np.meshgrid(grid_values, grid_values)
  loss_function = np.zeros((grid_values.size, grid_values.size))
  for idphi0, phi0 in enumerate(grid_values):
      for idphi1, phi1 in enumerate(grid_values):
          loss_function[idphi0, idphi1] = loss(phi1,phi0)
  return loss_function, phi0mesh, phi1mesh

# %%
# Define fancy colormap
my_colormap_vals_hex =('2a0902', '2b0a03', '2c0b04', '2d0c05', '2e0c06', '2f0d07', '300d08', '310e09', '320f0a', '330f0b', '34100b', '35110c', '36110d', '37120e', '38120f', '39130f', '3a1410', '3b1411', '3c1511', '3d1612', '3e1613', '3f1713', '401714', '411814', '421915', '431915', '451a16', '461b16', '471b17', '481c17', '491d18', '4a1d18', '4b1e19', '4c1f19', '4d1f1a', '4e201b', '50211b', '51211c', '52221c', '53231d', '54231d', '55241e', '56251e', '57261f', '58261f', '592720', '5b2821', '5c2821', '5d2922', '5e2a22', '5f2b23', '602b23', '612c24', '622d25', '632e25', '652e26', '662f26', '673027', '683027', '693128', '6a3229', '6b3329', '6c342a', '6d342a', '6f352b', '70362c', '71372c', '72372d', '73382e', '74392e', '753a2f', '763a2f', '773b30', '783c31', '7a3d31', '7b3e32', '7c3e33', '7d3f33', '7e4034', '7f4134', '804235', '814236', '824336', '834437', '854538', '864638', '874739', '88473a', '89483a', '8a493b', '8b4a3c', '8c4b3c', '8d4c3d', '8e4c3e', '8f4d3f', '904e3f', '924f40', '935041', '945141', '955242', '965343', '975343', '985444', '995545', '9a5646', '9b5746', '9c5847', '9d5948', '9e5a49', '9f5a49', 'a05b4a', 'a15c4b', 'a35d4b', 'a45e4c', 'a55f4d', 'a6604e', 'a7614e', 'a8624f', 'a96350', 'aa6451', 'ab6552', 'ac6552', 'ad6653', 'ae6754', 'af6855', 'b06955', 'b16a56', 'b26b57', 'b36c58', 'b46d59', 'b56e59', 'b66f5a', 'b7705b', 'b8715c', 'b9725d', 'ba735d', 'bb745e', 'bc755f', 'bd7660', 'be7761', 'bf7862', 'c07962', 'c17a63', 'c27b64', 'c27c65', 'c37d66', 'c47e67', 'c57f68', 'c68068', 'c78169', 'c8826a', 'c9836b', 'ca846c', 'cb856d', 'cc866e', 'cd876f', 'ce886f', 'ce8970', 'cf8a71', 'd08b72', 'd18c73', 'd28d74', 'd38e75', 'd48f76', 'd59077', 'd59178', 'd69279', 'd7937a', 'd8957b', 'd9967b', 'da977c', 'da987d', 'db997e', 'dc9a7f', 'dd9b80', 'de9c81', 'de9d82', 'df9e83', 'e09f84', 'e1a185', 'e2a286', 'e2a387', 'e3a488', 'e4a589', 'e5a68a', 'e5a78b', 'e6a88c', 'e7aa8d', 'e7ab8e', 'e8ac8f', 'e9ad90', 'eaae91', 'eaaf92', 'ebb093', 'ecb295', 'ecb396', 'edb497', 'eeb598', 'eeb699', 'efb79a', 'efb99b', 'f0ba9c', 'f1bb9d', 'f1bc9e', 'f2bd9f', 'f2bfa1', 'f3c0a2', 'f3c1a3', 'f4c2a4', 'f5c3a5', 'f5c5a6', 'f6c6a7', 'f6c7a8', 'f7c8aa', 'f7c9ab', 'f8cbac', 'f8ccad', 'f8cdae', 'f9ceb0', 'f9d0b1', 'fad1b2', 'fad2b3', 'fbd3b4', 'fbd5b6', 'fbd6b7', 'fcd7b8', 'fcd8b9', 'fcdaba', 'fddbbc', 'fddcbd', 'fddebe', 'fddfbf', 'fee0c1', 'fee1c2', 'fee3c3', 'fee4c5', 'ffe5c6', 'ffe7c7', 'ffe8c9', 'ffe9ca', 'ffebcb', 'ffeccd', 'ffedce', 'ffefcf', 'fff0d1', 'fff2d2', 'fff3d3', 'fff4d5', 'fff6d6', 'fff7d8', 'fff8d9', 'fffada', 'fffbdc', 'fffcdd', 'fffedf', 'ffffe0')
my_colormap_vals_dec = np.array([int(element,base=16) for element in my_colormap_vals_hex])
r = np.floor(my_colormap_vals_dec/(256*256))
g = np.floor((my_colormap_vals_dec - r *256 *256)/256)
b = np.floor(my_colormap_vals_dec - r * 256 *256 - g * 256)
my_colormap_vals = np.vstack((r,g,b)).transpose()/255.0
my_colormap = ListedColormap(my_colormap_vals)

# %%
# Plotting function
def draw_function(phi0mesh, phi1mesh, loss_function, my_colormap, opt_path):
    fig = plt.figure();
    ax = plt.axes();
    fig.set_size_inches(7,7)
    ax.contourf(phi0mesh, phi1mesh, loss_function, 256, cmap=my_colormap);
    ax.contour(phi0mesh, phi1mesh, loss_function, 20, colors=['#80808080'])
    ax.plot(opt_path[0,:], opt_path[1,:],'-', color='#a0d9d3ff')
    ax.plot(opt_path[0,:], opt_path[1,:],'.', color='#a0d9d3ff',markersize=10)
    ax.set_xlabel("")
    ax.set_ylabel("\phi_1}")
    plt.show()

# %%
# Simple fixed step size gradient descent
def grad_descent(start_posn, n_steps, alpha):
    grad_path = np.zeros((2, n_steps+1));
    grad_path[:,0] = start_posn[:,0];
    for c_step in range(n_steps):
        this_grad = get_loss_gradient(grad_path[0,c_step], grad_path[1,c_step]); #Grad w.r.t phi0, phi1
        grad_path[:,c_step+1] = grad_path[:,c_step] - alpha * this_grad
    return grad_path;
     
"""We'll start by running gradient descent with a fixed step size for this loss function."""
# Out:
# "We'll start by running gradient descent with a fixed step size for this loss function."

# %%
loss_function, phi0mesh, phi1mesh = get_loss_function_for_plot() ;

start_posn = np.zeros((2,1));
start_posn[0,0] = -0.7; start_posn[1,0] = -0.9

# Run "gradient descent"
grad_path1 = grad_descent(start_posn, n_steps=200, alpha = 0.08) # alpha가 작은 경우
draw_function(phi0mesh, phi1mesh, loss_function, my_colormap, grad_path1)
grad_path2 = grad_descent(start_posn, n_steps=40, alpha= 1.0) # alpha가 큰 경우
draw_function(phi0mesh, phi1mesh, loss_function, my_colormap, grad_path2)
     
"""Because the function changes much faster in $phi_1$ than in $phi_0$ 
, there is no great step size to choose. If we set the step size so that it makes sensible progress in the 
, then it takes many iterations to converge. If we set the step size so that we make sensible progress in the 
 direction, then the path oscillates in the 
 direction."""

"""This motivates Adam. At the core of Adam is the idea that 
we should just determine which way is downhill along each axis (i.e. left/right for 
 or up/down for 
) and move a fixed distance in that direction."""

"""
Phi1에서 phi0보다 훨씬 빠르게 하강하기 때문에
적절한 step size를 고르기 어려우며
phi0가 고려되지 않았기 때문에 많은 반복수를 필요로 한다.
그래서 Adam에서는 고정된 거리를 설정하여
모든 방향을 고려하도록 한다. 
"""
"""아래는 phi0에 대한 phi1 그래프"""
# Out:
# '아래는 phi0에 대한 phi1 그래프'

# %%
"""Motivation : Before ADAM, We observe the result of normalized gradient"""

def normalized_gradients(start_posn, n_steps, alpha,  epsilon=1e-20):
    grad_path = np.zeros((2, n_steps+1));
    grad_path[:,0] = start_posn[:,0];
    for c_step in range(n_steps):
        # Measure the gradient as in equation 6.13 (first line)
        m = get_loss_gradient(grad_path[0,c_step], grad_path[1,c_step]);
        # TO DO -- compute the squared gradient as in equation 6.13 (second line)
        # Replace this line:
        v = get_loss_gradient(grad_path[0,c_step], grad_path[1,c_step])**2;

        # TO DO -- apply the update rule (equation 6.14)
        # Replace this line:
        grad_path[:,c_step+1] = grad_path[:,c_step]-alpha*(m/(np.sqrt(v)+epsilon))
        
    return grad_path;

# %%
# Let's try out normalized gradients
start_posn = np.zeros((2,1));
start_posn[0,0] = -0.7; start_posn[1,0] = -0.9

# Run gradient descent
grad_path1 = normalized_gradients(start_posn, n_steps=40, alpha = 0.08)
draw_function(phi0mesh, phi1mesh, loss_function, my_colormap, grad_path1)
     
"""This moves towards the minimum at a sensible speed, 속도는 빠른데
but we never actually converge -- 수렴을 안한다
the solution just bounces back and forth between the last two points. 진동한다
To make it converge, we add momentum to both the estimates of the gradient 수렴시키기 위해서 모멘텀을 이용한다
and the pointwise squared gradient.
We also modify the statistics # 모멘텀과 같은 통계량들을 처음에는 빠르게 이동하고 나중에는 천천히 이동하도록 조정한다. 
by a factor that depends on the time to make sure the progress is now slow to start with."""
# Out:
# 'This moves towards the minimum at a sensible speed, 속도는 빠른데\nbut we never actually converge -- 수렴을 안한다\nthe solution just bounces back and forth between the last two points. 진동한다\nTo make it converge, we add momentum to both the estimates of the gradient 수렴시키기 위해서 모멘텀을 이용한다\nand the pointwise squared gradient.\nWe also modify the statistics # 모멘텀과 같은 통계량들을 처음에는 빠르게 이동하고 나중에는 천천히 이동하도록 조정한다. \nby a factor that depends on the time to make sure the progress is now slow to start with.'

# %%
"""Normalized Gradient는 모든 방향이 공평하게 고려되므로 수렴시키기 어렵다. 
따라서 현재 Gradient 대신 이전 Gradient의 영향을 더 높게 고려한 Momentum을 이용한다"""
def adam(start_posn, n_steps, alpha,  beta=0.9, gamma=0.99, epsilon=1e-20):
    grad_path = np.zeros((2, n_steps+1));
    grad_path[:,0] = start_posn[:,0];
    m = np.zeros_like(grad_path[:,0])
    v = np.zeros_like(grad_path[:,0])
    for c_step in range(n_steps):
        # Measure the gradient
        grad = get_loss_gradient(grad_path[0,c_step], grad_path[1,c_step])
        # TODO -- Update the momentum based gradient estimate equation 6.15 (first line)
        # Replace this line:
        m = beta*m+(1-beta)*grad;

        # TODO -- update the momentum based squared gradient estimate as in equation 6.15 (second line)
        # Replace this line:
        v = gamma*v+(1-gamma)*grad**2

        # TODO -- Modify the statistics according to equation 6.16
        # You will need the function np.power
        # Replace these lines
        m_tilde = m/(1-beta**(c_step+1))
        v_tilde = v/(1-gamma**(c_step+1))

        # TO DO -- apply the update rule (equation 6.17)
        # Replace this line:
        grad_path[:,c_step+1] = grad_path[:,c_step]-alpha*(m_tilde/(np.sqrt(v_tilde)+epsilon))

    return grad_path;

# %%
# Let's try out our Adam algorithm
start_posn = np.zeros((2,1));
start_posn[0,0] = -0.7; start_posn[1,0] = -0.9

# Run gradient descent
grad_path1 = adam(start_posn, n_steps=60, alpha = 0.05)
draw_function(phi0mesh, phi1mesh, loss_function, my_colormap, grad_path1)
loss_function
# Out:
# array([[0.90569773, 0.90529727, 0.9048975 , ..., 0.86589236, 0.86598452,
#         0.86607998],
#        [0.90186881, 0.90145209, 0.90103609, ..., 0.86044723, 0.86054314,
#         0.86064247],
#        [0.89792526, 0.8974918 , 0.89705908, ..., 0.8548391 , 0.85493886,
#         0.85504218],
#        ...,
#        [0.8938657 , 0.893415  , 0.89296506, ..., 0.84906598, 0.84916971,
#         0.84927714],
#        [0.89792526, 0.8974918 , 0.89705908, ..., 0.8548391 , 0.85493886,
#         0.85504218],
#        [0.90186881, 0.90145209, 0.90103609, ..., 0.86044723, 0.86054314,
#         0.86064247]])

# %%
def nadam(start_posn, n_steps, alpha, beta=0.9, gamma=0.99, epsilon=1e-20):
    grad_path = np.zeros((2, n_steps+1))
    grad_path[:,0] = start_posn[:,0]
    m = np.zeros_like(grad_path[:,0])
    v = np.zeros_like(grad_path[:,0])

    for c_step in range(n_steps):
        # 그라디언트 측정
        grad = get_loss_gradient(grad_path[0,c_step], grad_path[1,c_step])

        # 모멘텀 기반 그라디언트 추정치(m) 업데이트
        m = beta * m + (1 - beta) * grad

        # 모멘텀 기반 제곱 그라디언트 추정치(v) 업데이트
        v = gamma * v + (1 - gamma) * grad**2

        # 편향 수정된 첫 번째 모멘트 추정치 계산
        m_hat = m / (1 - np.power(beta, c_step + 1))

        # 편향 수정된 두 번째 원시 모멘트 추정치 계산
        v_hat = v / (1 - np.power(gamma, c_step + 1))

        # 네스테로프 가속 그라디언트 포함
        m_nesterov = beta * m_hat + (1 - beta) * grad

        # 업데이트 규칙 적용
        grad_path[:,c_step+1] = grad_path[:,c_step] - alpha * (m_nesterov / (np.sqrt(v_hat) + epsilon))

    return grad_path

# %%
# Let's try out our Adam algorithm
start_posn = np.zeros((2,1));
start_posn[0,0] = -0.7; start_posn[1,0] = -0.9

# Run gradient descent
grad_path1 = nadam(start_posn, n_steps=60, alpha = 0.05)
draw_function(phi0mesh, phi1mesh, loss_function, my_colormap, grad_path1)
print(loss_function)
# Out:
# [[0.90569773 0.90529727 0.9048975  ... 0.86589236 0.86598452 0.86607998]
#  [0.90186881 0.90145209 0.90103609 ... 0.86044723 0.86054314 0.86064247]
#  [0.89792526 0.8974918  0.89705908 ... 0.8548391  0.85493886 0.85504218]
#  ...
#  [0.8938657  0.893415   0.89296506 ... 0.84906598 0.84916971 0.84927714]
#  [0.89792526 0.8974918  0.89705908 ... 0.8548391  0.85493886 0.85504218]
#  [0.90186881 0.90145209 0.90103609 ... 0.86044723 0.86054314 0.86064247]]
